# %%
# %pwd
# Out:
# 'c:\\'

# %%
import os

# Automatically get path to current user's Desktop
desktop_path = os.path.join(os.environ["USERPROFILE"], "Desktop")
os.chdir(desktop_path)
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: C:\Users\Mohammad Ghalib\Desktop

# %%
# %pwd
# Out:
# 'C:\\Users\\Mohammad Ghalib\\Desktop'

# %%
# %pwd

# %%
import os

# Go to: C:\Users\<YourUsername>\Desktop\Atelier Online Fashion Store
desktop_path = os.path.join(os.environ["USERPROFILE"], "Desktop", "Atelier Online Fashion Store")
os.chdir(desktop_path)
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: C:\Users\Mohammad Ghalib\Desktop\Atelier Online Fashion Store

# %%
# %pwd
# Out:
# 'C:\\Users\\Mohammad Ghalib\\Desktop\\Atelier Online Fashion Store'

# %%
import os
os.chdir("../")

# %%
from langchain.document_loaders import PyPDFLoader,DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
 #Extract Data From the PDF File
def load_pdf_file(data):
    loader= DirectoryLoader(data,
                            glob="*.pdf",
                            loader_cls=PyPDFLoader)

    documents=loader.load()

    return documents

# %%
extracted_data=load_pdf_file(data='Data/')

# %%
extracted_data
# Out:
# [Document(metadata={'producer': 'Recoded by LuraDocument PDF v2.28', 'creator': 'Digitized by the Internet Archive', 'creationdate': '2011-02-04T21:33:45+00:00', 'title': 'The art of dressing well', 'keywords': 'http://www.archive.org/details/artofdressingwel00fros', 'author': 'Frost, S. Annie (Sarah Annie)', 'moddate': "D:20110204215219Z00'00'", 'source': 'Data\\artofdressingwel00fros.pdf', 'total_pages': 192, 'page': 0, 'page_label': ''}, page_content=''),
# ...

# %%
#Split the Data into Text Chunks
def text_split(extracted_data):
    text_splitter=RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=20)
    text_chunks=text_splitter.split_documents(extracted_data)
    return text_chunks

# %%
text_chunks=text_split(extracted_data)
print("Length of Text Chunks", len(text_chunks))
# Out:
# Length of Text Chunks 1195

# %%
text_chunks
# Out:
# [Document(metadata={'producer': 'Recoded by LuraDocument PDF v2.28', 'creator': 'Digitized by the Internet Archive', 'creationdate': '2011-02-04T21:33:45+00:00', 'title': 'The art of dressing well', 'keywords': 'http://www.archive.org/details/artofdressingwel00fros', 'author': 'Frost, S. Annie (Sarah Annie)', 'moddate': "D:20110204215219Z00'00'", 'source': 'Data\\artofdressingwel00fros.pdf', 'total_pages': 192, 'page': 1, 'page_label': ''}, page_content="Vo,\n'^ov-:^^\\.^*.^^-./^-^.\n''*ir^<i>c«j\n/Jlfc-\\..^^^:»^^o\\^^^/jtev^^0'o.*•A"),
# ...

# %%
from langchain.embeddings import HuggingFaceEmbeddings

# %%
#Download the Embeddings from Hugging Face
def download_hugging_face_embeddings():
    embeddings=HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
    return embeddings

# %%
embeddings = download_hugging_face_embeddings()
# Out:
# C:\Users\Mohammad Ghalib\AppData\Local\Temp\ipykernel_13392\2661704553.py:3: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings=HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')

# %%
query_result = embeddings.embed_query("Hello world")
print("Length", len(query_result))
# Out:
# Length 384

# %%
query_result
# Out:
# [-0.03447727486491203,
#  0.03102317824959755,
#  0.006734970025718212,
#  0.026108985766768456,
#  -0.03936202451586723,
#  -0.16030244529247284,
#  0.06692401319742203,
#  -0.006441489793360233,
#  -0.0474504791200161,
#  0.014758856035768986,
#  0.07087527960538864,
#  0.05552763119339943,
#  0.019193334504961967,
#  -0.026251312345266342,
#  -0.01010954286903143,
#  -0.02694045566022396,
#  0.022307461127638817,
#  -0.022226648405194283,
#  -0.14969263970851898,
#  -0.017493007704615593,
#  0.00767625542357564,
#  0.05435224249958992,
#  0.0032543970737606287,
#  0.031725890934467316,
#  -0.0846213847398758,
#  -0.02940601296722889,
#  0.05159561336040497,
#  0.04812406003475189,
#  -0.0033148222137242556,
#  -0.058279167860746384,
#  0.04196927323937416,
#  0.022210685536265373,
#  0.1281888335943222,
#  -0.022338971495628357,
#  -0.011656315997242928,
#  0.06292839348316193,
#  -0.032876335084438324,
#  -0.09122604131698608,
#  -0.031175347045063972,
#  0.0526994913816452,
# ...

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
PINECONE_API_KEY=os.environ.get('PINECONE_API_KEY')
OPENAI_API_KEY=os.environ.get('OPENAI_API_KEY')

# %%
from pinecone.grpc import PineconeGRPC as Pinecone
from pinecone import ServerlessSpec
import os

pc = Pinecone(api_key=PINECONE_API_KEY)

index_name = "atelier"


pc.create_index(
    name=index_name,
    dimension=384, 
    metric="cosine", 
    spec=ServerlessSpec(
        cloud="aws", 
        region="us-east-1"
    ) 
)
# Out:
# {
#     "name": "atelier",
#     "metric": "cosine",
#     "host": "atelier-iomqw9u.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "cloud": "aws",
#             "region": "us-east-1"
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 384,
#     "deletion_protection": "disabled",
#     "tags": null
# }

# %%
import os
os.environ["PINECONE_API_KEY"] = PINECONE_API_KEY
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
# Embed each chunk and upsert the embeddings into your Pinecone index.
from langchain_pinecone import PineconeVectorStore

docsearch = PineconeVectorStore.from_documents(
    documents=text_chunks,
    index_name=index_name,
    embedding=embeddings, 
)

# %%
# Load Existing index 

from langchain_pinecone import PineconeVectorStore
# Embed each chunk and upsert the embeddings into your Pinecone index.
docsearch = PineconeVectorStore.from_existing_index(
    index_name=index_name,
    embedding=embeddings
)

# %%
docsearch

# %%
retriever = docsearch.as_retriever(search_type="similarity", search_kwargs={"k":3})

# %%
retrieved_docs = retriever.invoke("What is fashion?")

# %%
retrieved_docs
# Out:
# [Document(id='b54d8484-c33d-4236-8c1d-cb200102edf3', metadata={'author': 'Anamika', 'creationdate': '2024-03-26T20:54:57+00:00', 'creator': 'Canva', 'keywords': 'DAFuJuMc2Z0,BAEuqw3Mu5k', 'moddate': '2024-03-26T20:54:40+00:00', 'page': 4.0, 'page_label': '5', 'producer': 'Canva', 'source': 'Data\\The-Definitive-Guide-To-Dress-Design--Ebook-.pdf', 'title': 'Dress Ebook Draft: The Definitive Guide To Dress Design', 'total_pages': 64.0}, page_content='era. Today, fashion is more diverse and inclusive than ever, with styles\ninfluenced by a wide range of factors, including globalization,\ntechnology, and sustainability.'),
# ...

# %%
from langchain_openai import OpenAI
llm = OpenAI(temperature=0.4, max_tokens=500)

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate


system_prompt = (
    "You are an assistant for fashion and style dressing help. "
    "Use the following pieces of retrieved context to answer "
    "the question. If you don't know the answer, say that you "
    "For fashion ,most colors blend properly,especially black and white, check out our store for more info. Use three sentences maximum and keep the "
    "answer concise."
    "\n\n"
    "{context}"
)


prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}"),
    ]
)

# %%
question_answer_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# %%
response = rag_chain.invoke({"input": "How can i dress for an interview?"})
print(response["answer"])
# Out:
# As a fashion assistant, I can advise you to dress conservatively for an interview. Stick to dark colors like black, gray/charcoal, or navy blue and pair it with a white shirt and solid tie. It's important to make sure your suit fits well and is not too tight. If you need help making decisions about your outfit, consider seeking assistance from a professional at a high-end department store.
